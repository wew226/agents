# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AI
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# You're advising the government of a small, middle‑income coastal democracy (10 million people, GDP per capita ~$8k, public debt ~60% GDP) that faces: sea‑level rise threatening habitable land and livelihoods for 10% of the population over 30 years; rapid AI and automation likely to displace roughly 25% of current jobs within a decade; heavy dependence on a single export commodity; rising inequality and growing political polarization; and very limited fiscal space — design a prioritized, integrated 10‑year strategy that will (1) protect and adapt vulnerable populations to climate displacement, (2) manage technological unemployment while fostering broadly shared economic growth, and (3) diversify and harden the economy against external shocks. For each of the three goal areas, specify: the top 6 policy interventions you would implement (legal/regulatory, fiscal, social, educational, infrastructural, and international/political), the sequencing and timelines (what to do in years 0–2, 3–5, 6–10), rough order‑of‑magnitude cost estimates and realistic financing options, and 5 concrete, measurable metrics to evaluate progress. Then identify the three most plausible failure modes for the overall strategy, explain contingency plans for each, and for every major policy recommendation list the key assumptions that must hold and the specific empirical indicators that would cause you to revise or abandon the recommendation. Finally, give the three strongest counterarguments critics would make against your integrated plan and provide concise rebuttals to each, and conclude with a probabilistic estimate (with brief justification) of the chance that your strategy will achieve measurable improvement on each of the three goals within 10 years.

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Below is a compact, integrated 10-year strategy tailored to a small, middle‑income coastal democracy with about 10 million people, GDP per capita around $8,000 (roughly $80B GDP), public debt near 60% of GDP, and the triple stress of climate risk, rapid AI/automation, and export‑dependency. The plan balances protection of vulnerable people, active labor market policy, and diversification/hardening of the economy, while staying within a plausible fiscal envelope and leveraging international finance and regional partnerships.
#
# Assumptions used in this plan (high level)
# - GDP ≈ $80B; debt ≈ $48B (60% of GDP). Some fiscal space exists but not unlimited; concessional sources are available for climate/transition initiatives.
# - Climate risk: 10% of the population faces climate-displacement risk over ~30 years; managed relocation is feasible with housing, jobs, and social protection.
# - AI/automation: ~25% of current jobs may be displaced within a decade; demand for new skills will exist but requires scale-up of retraining and job‑creation programs.
# - External shocks risk remains high; diversification reduces susceptibility to commodity-price swings.
# - Political space is limited; reforms must be gradual, transparent, and anchored in universal social protections to maintain social cohesion.
#
# Section A. Goal 1 — Protect and adapt vulnerable populations to climate displacement (top 6 interventions)
# Interventions (covering regulatory, fiscal, social, educational, infrastructural, and international/political)
# 1) Legal/regulatory: National Managed Relocation Framework
# - What: Enact a clear legal framework for planned relocation, land/house rights, compensation, and durable housing for climate-displaced households; establish interagency coordination rules.
# - Rationale: Reduces delays, protects rights, and eliminates ad hoc relocation inefficiencies.
# - Key assumption: Law is enacted, harmonized across jurisdictions, and people have trust in processes.
# - Indicators that would force revision: low compliance, litigation spikes, or relocation pace far below targets.
# 2) Fiscal: Climate Adaptation Fund + targeted local grants (0.2–0.6% of GDP per year)
# - What: Create a dedicated fund for relocation-related housing, infrastructure, and social protection; access concessional climate finance; use grants/low‑interest loans for pilot sites.
# - Assumption: Access to concessional finance; governance, transparency, and outputs evidenced by fund disbursement.
# - Indicators: Fund capitalization, disbursement rate, cost per unit of housing completed, and share of displaced households with shelter.
# 3) Social protection: Climate-displacement social safety nets and cash/inkind support
# - What: Scalable cash transfers, healthcare continuity, education continuity (schools in host communities), and targeted subsidies for affected families.
# - Assumption: Administrative systems can reliably identify beneficiaries and deliver benefits.
# - Indicators: Coverage rate of vulnerable groups, time-to-delivery metrics, poverty/food-security trends among displaced populations.
# 4) Educational/training: Climate-resilience and relocation-relevant skills in curricula and local capacity-building
# - What: Integrate climate-resilience, basic construction, hazard mapping, and disaster‑risk governance into vocational and school curricula; train local government staff.
# - Assumption: Curriculum adoption and teacher training succeed; local capacity improves.
# - Indicators: Number of teachers trained, curricula integrated, and students completing resilience modules; competency gains in hazard-risk assessments.
# 5) Infrastructural: Climate-proofing and relocation-site infrastructure
# - What: Build climate-resilient housing, flood defenses, early-warning systems, and relocation sites with essential services; invest in nature-based defenses where feasible.
# - Assumption: Procurement, land-use planning, and timely construction are achievable; maintenance funding exists.
# - Indicators: Kilometers of flood defenses completed, housing units delivered, time to provide services (water/electricity) at relocation sites.
# 6) International/political: Regional cooperation and mobility channels
# - What: Partner with neighboring countries for labor mobility, temporary migration for climate-impacted regions, and regional disaster risk financing arrangements.
# - Assumption: Regional agreements are negotiated and operational; remittance flows and labor mobility rise as planned.
# - Indicators: Signed regional mobility agreements, number of migrants in shared programs, remittance volumes, and integration in local economies.
#
# Sequencing and timelines
# - Years 0–2
#   - Pass and publish the Managed Relocation Framework; establish the Climate Adaptation Fund governance; map high-risk areas; pilot relocations in a few districts; begin social protection roll-out.
# - Years 3–5
#   - Scale relocation to additional sites; expand housing stock and early-warning/infrastructure; broaden education/training modules; deepen regional labor-mobility agreements; begin tracking long‑term social outcomes.
# - Years 6–10
#   - Full-scale managed-relocation capacity; annual evaluation of housing adequacy and social outcomes; refine risk-mapping; sustain regional disaster-finance arrangements; consolidate social protections and housing rights.
# Cost estimates and financing options (order-of-magnitude)
# - Total 10-year cost (goal-wide within Goal 1): roughly 0.2–0.6% of GDP per year on average → about $160–480 million per year; aggregate ≈ $1.6–4.8B (highly contingent on site scale and housing costs).
# - Financing mix:
#   - Domestic budget reallocation and near-term savings from risk-prioritization (municipal/land-use efficiencies).
#   - Concessional climate finance (Green Climate Fund, regional development banks).
#   - Sovereign/green bonds and diaspora bonds dedicated to climate-relocation programs.
#   - Public–private partnerships for housing and service delivery where feasible.
# Measurable metrics (5)
# - % of households in hazard-mapped zones with formal relocation rights; relocation completion rate per year; average time to deliver housing and services to relocated households; share of displaced households receiving cash/in-kind protection; incidence of climate-related extreme events in relocated populations.
#
# Assumptions and indicators (per policy)
# - Assumption: Finance remains available; governance can execute projects; relocation sites attract adequate social services.
# - Indicators for revision: inadequate capital inflows; governance failures (corruption, delays); relocation pace far below targets; protests or social unrest related to relocations.
#
# Section B. Goal 2 — Manage technological unemployment while fostering broadly shared growth (top 6 interventions)
# Interventions
# 1) Regulatory/standards: National Skills Transformation Framework
# - What: Establish national standards for digital literacy, AI/automation readiness, and sectoral retraining pathways; accrediting bodies; portable credentials.
# - Assumption: Employers recognize credentials; training providers meet quality standards.
# - Indicators: Standards adopted; number of providers with accreditation; share of workers with portable credentials; job placements from credential holders.
# 2) Fiscal: Wage subsidies and firm-investment incentives for retraining
# - What: Targeted wage subsidies for jobs created in training-to-work pipelines; tax credits or subsidies for firms that retrain workers or hire graduates of the program.
# - Assumption: Subsidies reduce hiring costs and improve retention; leakage is manageable.
# - Indicators: Jobs created through subsidy programs; retention 12–24 months after hire; cost per job created.
# 3) Social protections: Portable, subsidized unemployment insurance and job guarantees for retraining periods
# - What: Expand unemployment benefits with portability across jobs and regions; temporary job guarantees (e.g., public-sector, climate-work).
# - Assumption: Administrative capacity to deploy benefits; funds remain solvent.
# - Indicators: Coverage rate; average duration of unemployment benefits; rate of successful transitions to employment.
# 4) Educational focus: Lifelong learning, microcredentials, and industry‑funded training
# - What: Expand microcredentials in AI, data analytics, cybersecurity, software development; incentivize industry-funded programs; flexible learning schedules.
# - Assumption: Training aligns with private-sector demand; providers scale.
# - Indicators: Enrollments in retraining programs; credential completions; time-to-employ after credential.
# 5) Infrastructural: Broadband and digital public goods; access in rural areas
# - What: Ensure universal or near-universal broadband; invest in digital learning platforms, e-health, and e-government services to support learning and training.
# - Assumption: Connectivity and platforms function at scale; households can access devices.
# - Indicators: % households with reliable broadband; usage rates of e-learning platforms; digital-literacy test score improvements.
# 6) International/political: Regional and bilateral talent-development partnerships
# - What: Partner with neighboring countries and global players for joint training programs, exchange schemes, and temporary work arrangements.
# - Assumption: Mobility regimes and visa policies are workable; funding for cross-border programs.
# - Indicators: Number of bilateral training programs; migrants in cross-border apprenticeships; remittance flows tied to training outcomes.
#
# Sequencing and timelines
# - Years 0–2
#   - Launch Skills Transformation Framework; establish accreditation; pilot wage subsidies with select sectors (manufacturing, logistics, hospitality, health tech); roll out universal broadband program.
# - Years 3–5
#   - Scale retraining across sectors; broaden microcredentials; implement job guarantees for low-skilled transitions; extend regional training partnerships; mainstream portable benefits.
# - Years 6–10
#   - Deep integration of lifelong learning; mature private-sector funding streams; expand regional mobility; evaluate labor-market outcomes and recalibrate programs to demand shifts.
# Cost estimates and financing options (order-of-magnitude)
# - Total 10-year cost: roughly 0.4–1.0% of GDP per year on average → about $320–800 million per year; aggregate ≈ $3.2–8.0B.
# - Financing mix:
#   - Domestic budget prioritization and savings from productivity improvements.
#   - Employer and industry-funded training funds; payroll-based contributions where feasible.
#   - International development finance and blended finance mechanisms (MDBs, DFIs) to co-finance campus/training infrastructure.
#   - Public–private partnerships for regional skills hubs and digital platforms.
# Measurable metrics (5)
# - Unemployment rate among previously displaced workers; share of workforce with AI/digital credentials; job-placement rates after retraining; wage growth for program participants; private-sector absorption of trained workers.
#
# Assumptions and indicators (per policy)
# - Assumption: Labor market demand remains robust enough to absorb trained workers; private sector participates in co-funding and hiring.
# - Indicators for revision: persistent underemployment or overtraining in certain cohorts; credential mismatch with jobs; rapid policy fiscal overrun.
#
# Section C. Goal 3 — Diversify and harden the economy against external shocks (top 6 interventions)
# Interventions
# 1) Regulatory/policy: Export diversification and commodity revenue management
# - What: Formal export-diversification strategy, enhanced export controls, and rules to stabilize commodity revenue (transparent fiscal rules, revenue smoothing, compulsory savings in a sovereign fund).
# - Assumption: Diversification opportunities exist; investor confidence improves; commodity revenue is stabilized to fund diversification.
# - Indicators: Share of non-commodity exports; revenue volatility; investment flows into diversified sectors.
# 2) Fiscal: Commodity revenue stabilization fund and sovereign wealth management
# - What: Create a stabilization facility or sovereign wealth fund to dampen commodity revenue swings and fund long-term diversification.
# - Assumption: Clear governance, professional management, and prudent withdrawal rules.
# - Indicators: Fund size; payout stability; diversification of assets.
# 3) Local development/social: Local content requirements and SME development
# - What: Promote local procurement, SME financing, and value-chain strengthening in new sectors (aerospace, renewables, agro-tech).
# - Assumption: Local firms can scale; procurement rules do not deter investment.
# - Indicators: Local procurement share; SME credit access; number of local firms in value chains.
# 4) Educational/training: Vocational and university programs aligned to emerging industries
# - What: Targeted programs in renewable energy, marine tech, logistics, agri-tech; support for research and demonstration projects.
# - Assumption: Programs align with demand from new sectors; institutions can scale.
# - Indicators: Labor-market match rates; number of industry-sponsored research projects; graduates employed in target sectors.
# 5) Infrastructural: Resilient infrastructure and logistics hubs
# - What: Upgrades to ports, logistics corridors, energy systems (grid resilience, storage, diversification to renewables), climate-resilient coastal infrastructure.
# - Assumption: Financing and procurement timelines align; long-term maintenance is funded.
# - Indicators: Port throughput; energy reliability metrics; time-to-delivery for major projects; disaster-related outages.
# 6) International/political: Regional trade integration and climate/energy partnerships
# - What: Deeper regional trade ties; joint investment in trans-regional logistical corridors; climate-resilience and green-energy partnerships.
# - Assumption: Regional partners maintain policy commitment; trade facilitation measures are effective.
# - Indicators: Regional trade volumes; number of cross-border investments; joint climate/energy projects signed.
#
# Sequencing and timelines
# - Years 0–2
#   - Diagnostic of export dependence; establish stabilization fund governance framework; begin port/logistics modernization planning; initiate first round of local content and SME programs.
# - Years 3–5
#   - Implement diversification investments in select sectors (renewables, agritech, marine technologies); deploy regional trade agreements and logistics corridors; expand local procurement rules.
# - Years 6–10
#   - Scale diversification across more sectors; solidify sovereign fund rules; operationalize large-scale climate/energy partnerships; monitor external shock resilience indicators.
# Cost estimates and financing options (order-of-magnitude)
# - Total 10-year cost: roughly 0.3–0.7% of GDP per year → $240–560 million per year; aggregate ≈ $2.4–5.6B.
# - Financing mix:
#   - Regional/multilateral lending for infrastructure (MDBs, regional development banks).
#   - Sovereign wealth fund contributions and inward capital from commodity revenues.
#   - Green/Crowth bonds and public-private partnerships for strategic assets.
#   - International trade finance facilities to broaden export markets.
# Measurable metrics (5)
# - Share of non-commodity exports; diversification index (by sector and geography); volatility of commodity revenue; size and performance of the sovereign fund; port/logistics performance metrics (throughput, dwell times).
#
# Assumptions and indicators (per policy)
# - Assumption: Diversification opportunities exist and can be scaled; governance of the stabilizing fund is credible.
# - Indicators for revision: Persistent reliance on a single export, deteriorating fiscal balance, or governance concerns around fund management.
#
# Section D. Sequencing summary by year bands (high level)
# - Years 0–2: Legal/regulatory foundations (relocation; skills framework; export diversification policy draft); establish funds and governance; pilot programs (relocation sites, initial retraining cohorts, and initial port/logistics assessments); begin regional cooperation talks.
# - Years 3–5: Scale relocation and training; broaden diversification investments; enlarge social protections; expand regional mobility and trade initiatives; initiate large-scale infrastructure projects with first tranche financing.
# - Years 6–10: Full implementation; refine policies based on monitoring results; deepen regional and international partnerships; consolidate debt- and risk-management; sustain momentum with periodic independent reviews.
#
# Three most plausible failure modes and contingency plans
# 1) Financing gaps and debt sustainability risk
# - Failure mode: The plan’s cumulative cost outstrips available concessional finance and domestic revenue capacity, threatening debt sustainability.
# - Contingency plan:
#   - Lock in a strict, transparent, multi-year debt and fiscal framework; broaden concessional finance sources; escalate grant-based support for climate/transition projects; pause non-core activities if indicators signal unsustainable debt dynamics; pursue debt-relief/frost options with creditors if needed.
# - Indicators triggering revision: debt-to-GDP rising above a predetermined ceiling; financing gap > target range; cost overruns on flagship projects; downgrade of sovereign credit rating.
# 2) Political polarization and governance bottlenecks
# - Failure mode: Reform fatigue, protests, or political brinkmanship slows implementation or reverses reforms.
# - Contingency plan:
#   - Strengthen inclusive governance; establish independent watchdogs; widen social protections to build broad-based legitimacy; set sunset clauses and clear evaluation milestones; implement participatory budgeting for key projects; secure cross-party commitments.
# - Indicators triggering revision: persistent social conflict; failure to pass repealing or implementing key reforms; budget overruns due to governance delays.
# 3) AI/automation displacement outpaces retraining and job creation
# - Failure mode: The pace of AI/automation exceeds the capacity of retraining programs; unemployment rises persistently despite policy.
# - Contingency plan:
#   - Accelerate prioritized public-work programs; deploy wage subsidies more aggressively; implement a time-limited universal basic income or guaranteed minimum income pilot in high-risk regions; relax visa policies for skilled workers if needed to attract talent; accelerate regional labor-mlooding through mobility programs.
# - Indicators triggering revision: unemployment rate among mid-to-low skill workers remains high after retraining; retraining completion rates drop; mismatch between skill supply and demand remains high.
#
# Assumptions and indicators for major policy recommendations (per intervention)
# - For each policy, key assumptions and indicators to watch
#   - Relocation Framework: Assumptions: legal coherence and land rights enforcement; acceptance by communities; available housing stock. Indicators: number of people legally recognized; length of time to relocate; incidents of dispute resolution.
#   - Climate Adaptation Fund: Assumptions: adequate concessional funds; transparent allocation. Indicators: fund capitalization; disbursement pace; project completion rates; beneficiary satisfaction.
#   - Social protection for displaced: Assumptions: administrative capacity; targeted delivery. Indicators: coverage rates; average benefit delivery time; poverty rates among displaced.
#   - Education/training in climate resilience: Assumptions: demand for skills; providers scaling; quality assurance. Indicators: credential completions; job placements from programs; employer satisfaction.
#   - Infrastructure resilience: Assumptions: procurement, land-use, and maintenance funding. Indicators: project completion times; defect rates; service continuity during climate events.
#   - Regional mobility agreements: Assumptions: policy alignment and visa rules. Indicators: number of mobility slots used; remittance flows; cross-border employment.
#   - Skills transformation standards: Assumptions: employer recognition; quality of training. Indicators: provider accreditation; alignment between credentials and job openings; earn-while-you-learn metrics.
#   - Wage subsidies and firm incentives: Assumptions: program targeting; leakage control; fiscal space. Indicators: jobs subsidized; retention rates; cost per job.
#   - Portable unemployment insurance: Assumptions: funding and administration. Indicators: coverage; benefit timeliness; fraud rate.
#   - Lifelong learning and microcredentials: Assumptions: demand and affordability. Indicators: enrollments; credentials earned; industry absorption.
#   - Broadband/digital platforms: Assumptions: universal service funding; device access. Indicators: broadband penetration; platform usage; digital-literacy gains.
#   - Regional training partnerships: Assumptions: political will and financing. Indicators: programs signed; participants; cross-border job placements.
#   - Diversification agenda (export diversification, stabilization fund, local content, etc.): Assumptions: demand for diversified goods; credible fund governance. Indicators: share of exports outside commodity; fund balance and withdrawals; local procurement share.
#
# Three strongest counterarguments critics would make (and rebuttals)
# - Counterargument 1: The plan is too expensive given debt and limited fiscal space; cannot deliver a credible return on investment.
#   - Rebuttal: The plan is staged and flexible, with a strong emphasis on concessional finance, regional cooperation, and private-sector co-funding. It prioritizes high-yield, high-impact investments (climate resilience, diversified exports, and human-capital development), which reduce exposure to commodity shocks and AI disruption. By improving growth potential and social resilience, it lowers risk of debt distress and creates revenue-positive feedback loops (higher growth, better tax base, reduced social costs).
# - Counterargument 2: Government-led “picking winners” distorts markets and crowds out private investment.
#   - Rebuttal: The strategy is not a blind public-sector subsidy; it provides a framework that enables the private sector (through standards, investment climate, and targeted incentives) to invest in areas with proven spillovers (skills, infrastructure, diversified exports). Clear sunset clauses, performance metrics, independent oversight, and competitive bidding reduce distortions. The aim is to reduce market failures (skills gaps, capital shortages, and risk premia) that prevent private investment from happening.
# - Counterargument 3: Focus on AI/automation and diversification neglects traditional sectors and coastal livelihoods that are already fragile.
#   - Rebuttal: The plan integrates both: protection of vulnerable people (Goal 1) and diversification (Goal 3) directly address coastal livelihoods while expanding new opportunities (Goal 2). Policy design includes social safety nets and relocation where needed, ensuring those most at risk aren’t left behind. Diversification reduces exposure to a single commodity and creates new, climate-resilient jobs along the coast (renewables, logistics, fisheries tech, ecotourism, etc.). It’s an adaptive, all‑of‑the‑above approach, not a single-track policy.
#
# Probabilistic assessment of 10-year outcomes (chance of measurable improvement)
# - Climate displacement protection (Goal 1): moderate probability, around 35–50%.
#   - Why: If governance frameworks, funds, housing supply, and regional cooperation deliver as scheduled, displacement pressure will be better managed and housing/relocation rights protected. Risk: capital constraints or governance issues could slow progress, and relocation pace may lag.
# - Technological unemployment management (Goal 2): modest probability, around 30–45%.
#   - Why: If skills programs scale quickly and private firms participate, retraining outcomes improve and new jobs emerge. Risk: global tech demand shifts, spillovers, or mismatches between skills and available roles can limit impact.
# - Diversification and economic hardening (Goal 3): modest-to-moderate probability, around 25–40%.
#   - Why: Diversification and regional partnerships can stabilize growth and reduce commodity dependence, but require sustained political will, capital, and global demand for diversified exports. Risk: slow external demand, elevated financing costs, or governance bottlenecks could impede progress.
#
# What would constitute “success” in 10 years?
# - Goal 1: Measurable protection of vulnerable populations with substantially lower displacement distress; housing security for relocated households; stabilized or increased access to essential services and livelihoods for climate-affected residents.
# - Goal 2: A reduce-to-neutral rate of structural unemployment affecting those displaced by automation; a measurable increase in the share of workforce with in-demand digital and advanced-technical skills; private investment in AI/automation-friendly sectors.
# - Goal 3: A diversified export base with a lower correlation to one commodity, higher resilience to external shocks, and demonstrable investments in climate-resilient infrastructure and energy.
#
# Closing remarks
# - The plan is deliberately integrated: climate resilience and social protection (Goal 1) stabilize vulnerable populations and set a humane baseline; workforce transformation (Goal 2) mitigates the most disruptive effects of AI; diversification/hardening (Goal 3) reduces exposure to commodity cycles and builds resilience to external shocks. Financing rests on a mix of concessional funds, private investment, domestic revenue reforms, and prudent debt management; governance and transparency are central to delivering results and maintaining social legitimacy.
# - If you want, I can repackage this into a one-page executive summary with a succinct table of the 18 policy interventions (6 per goal) plus the high-level budget ranges and the top 5 indicators for each goal.

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-sonnet-4-5"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# # Integrated 10-Year National Resilience Strategy
#
# ## GOAL 1: Protect and Adapt Vulnerable Populations to Climate Displacement
#
# ### Top 6 Policy Interventions
#
# **1. LEGAL/REGULATORY: Coastal Zone Management & Planned Retreat Framework**
# - **Years 0-2:** Enact Coastal Adaptation Act establishing: mandatory climate risk disclosure for coastal property; building moratorium in highest-risk zones; legal framework for government land acquisition at fair market value; "climate mobility rights" guaranteeing resettlement assistance
# - **Years 3-5:** Implement zoning transitions; begin systematic buyout program for 10,000 highest-risk properties
# - **Years 6-10:** Complete relocation of 50% of at-risk population (100,000 households)
# - **Cost:** $800M-1.2B over 10 years ($15-20k/household relocation assistance)
# - **Financing:** Green Climate Fund grants ($200M), domestic climate bonds ($400M), land value capture from development in safer zones ($400M)
# - **Key Assumption:** International climate finance remains available; property values don't collapse before managed buyouts begin
# - **Revision Indicator:** If property market crashes >40% before Year 2, accelerate buyout timeline and increase compensation
#
# **2. FISCAL: Climate Adaptation Fund with Progressive Financing**
# - **Years 0-2:** Establish 0.5% carbon tax on fossil fuels; 2% luxury property tax on high-value coastal real estate; redirect 20% of commodity export revenues
# - **Years 3-5:** Scale to 1% carbon tax; issue $500M climate adaptation bonds
# - **Years 6-10:** Self-sustaining fund generating $150-200M annually
# - **Cost:** Revenue-positive after Year 3; initial administrative costs $5M
# - **Financing:** Self-financing through designated revenues
# - **Key Assumption:** Carbon tax doesn't trigger political backlash; export commodity prices remain stable
# - **Revision Indicator:** If commodity prices fall >30% sustained, pivot to international debt-for-climate swaps
#
# **3. SOCIAL: Universal Climate Displacement Insurance**
# - **Years 0-2:** Design parametric insurance covering 100% of coastal vulnerable population; establish Climate Displacement Support Agency
# - **Years 3-5:** Full enrollment; automatic payouts triggered by sea-level benchmarks, storm damage
# - **Years 6-10:** Expand to drought/agricultural climate risks
# - **Cost:** $300M over 10 years (premiums + administrative)
# - **Financing:** African Risk Capacity/CCRIF-style risk pooling ($120M), budget allocation ($100M), international reinsurance ($80M)
# - **Key Assumption:** Actuarial models accurately predict climate impacts; international reinsurance markets remain accessible
# - **Revision Indicator:** If claims exceed projections by >50% in first 3 years, reduce coverage or increase premiums
#
# **4. EDUCATIONAL: Climate Resilience Skills Academy**
# - **Years 0-2:** Establish technical training centers in 3 regional hubs; curricula for green construction, renewable energy installation, climate-smart agriculture, coastal ecosystem management
# - **Years 3-5:** Train 25,000 workers; certify 5,000 in specialized climate adaptation professions
# - **Years 6-10:** Scale to 60,000 trained; establish as regional center of excellence
# - **Cost:** $150M (infrastructure + operations)
# - **Financing:** Bilateral development aid ($70M), domestic training levy on large firms ($50M), World Bank skills development loan ($30M)
# - **Key Assumption:** Labor demand for green skills materializes; training quality remains high
# - **Revision Indicator:** If graduate employment rates fall below 60%, restructure curricula based on market signals
#
# **5. INFRASTRUCTURAL: Resilient Relocation Zones Development**
# - **Years 0-2:** Identify and acquire land for 3 "climate resilience cities" in geologically stable inland/higher-elevation areas; master planning with climate-proof infrastructure standards
# - **Years 3-5:** Build core infrastructure (water, power, transport) and 15,000 affordable housing units using modular construction
# - **Years 6-10:** Complete 40,000 units; attract private sector investment in commercial development
# - **Cost:** $2.5B (land

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# The government of this small, middle-income coastal democracy faces an extraordinary confluence of challenges: an existential climate threat, disruptive technological shifts, structural economic vulnerabilities, and escalating social tensions, all compounded by severe fiscal constraints. A reactive, piecemeal approach is insufficient; a proactive, integrated 10-year strategy is imperative to ensure national survival and prosperity.
#
# This strategy is built on three pillars: **Human Capital Resilience, Climate-Adaptive Development, and Economic Hardening**. It prioritizes interventions that offer co-benefits across multiple goals, leverage international partnerships, and foster broad societal buy-in to navigate a turbulent future.
#
# ---
#
# ## Integrated 10-Year National Resilience Strategy
#
# **Overarching Vision:** To transform into a high-skill, diversified, climate-resilient economy that offers shared prosperity and protects its citizens from future shocks.
#
# **Core Principles:**
# 1.  **Proactive Adaptation:** Act now to mitigate future, more costly crises.
# 2.  **Human-Centric Development:** Invest in people as the primary engine of adaptation and growth.
# 3.  **Fiscal Prudence & Innovative Finance:** Maximize impact of limited resources, aggressively pursue external funding.
# 4.  **Data-Driven Governance:** Base decisions on evidence, monitor progress, and adapt rapidly.
# 5.  **National Cohesion:** Foster dialogue and shared ownership to overcome polarization.
#
# ---
#
# ### Goal 1: Protect and Adapt Vulnerable Populations to Climate Displacement
#
# **Objective:** Secure the lives, livelihoods, and cultural heritage of the 10% of the population (1 million people) threatened by sea-level rise, ensuring an orderly and equitable transition.
#
# #### Top 6 Policy Interventions:
#
# 1.  **Legal/Regulatory: Comprehensive Coastal Zone Management & Resettlement Act (CZMRA)**
#     *   Establishes clear legal frameworks for land use in vulnerable zones, restricts new construction, mandates climate-resilient building codes, and provides legal pathways for voluntary and planned relocation, including fair compensation and land swaps.
# 2.  **Infrastructural: Strategic "Hard & Soft" Coastal Protection & Early Warning Systems**
#     *   Invest in a mix of grey infrastructure (targeted sea walls, storm surge barriers for critical areas) and green infrastructure (mangrove restoration, coral reef protection, dune stabilization). Develop a real-time, nation-wide multi-hazard early warning system integrated with community response protocols.
# 3.  **Social: Climate Relocation and Livelihood Transition Program (CRLTP)**
#     *   Offers financial assistance, housing support, vocational training (e.g., aquaculture, climate-smart agriculture, eco-tourism), and psychosocial support for displaced communities. Prioritizes community-led relocation where feasible, preserving social fabric.
# 4.  **Fiscal: National Climate Adaptation Fund (NCAF) & Green Bonds**
#     *   Establish a dedicated fund, capitalized by a domestic carbon tax, international climate finance, and potentially sovereign green bonds, to finance CZMRA enforcement, CRLTP, and other adaptation projects.
# 5.  **Educational: Climate Literacy & Adaptation Skills Curriculum**
#     *   Integrate climate change impacts, adaptation strategies, and associated green skills (e.g., sustainable construction, water management) into primary, secondary, and vocational education.
# 6.  **International/Political: Aggressive Climate Diplomacy & Bilateral Partnerships**
#     *   Actively engage with UNFCCC, GCF, Adaptation Fund, and bilateral donors (e.g., EU, Japan, Australia, US) to secure grants, concessional loans, and technical assistance for climate adaptation, emphasizing the nation's unique vulnerability and proactive stance.
#
# #### Sequencing and Timelines:
#
# *   **Years 0-2 (Foundation & Urgent Planning):**
#     *   Pass CZMRA (Legal). Establish NCAF (Fiscal). Conduct high-resolution vulnerability mapping and risk assessment. Pilot CRLTP for 2-3 most critically threatened communities (Social). Initiate design and feasibility studies for strategic hard infrastructure and early warning systems (Infrastructural). Launch climate literacy campaigns (Educational).
#     *   **Cost Estimate:** $50-100 million (initial studies, legal drafting, pilot programs, international engagement).
#     *   **Financing:** Primarily international grants and technical assistance (GCF, bilateral aid), initial domestic carbon tax revenue.
# *   **Years 3-5 (Scaling & Mid-term Implementation):**
#     *   Expand CRLTP to 20-30 communities, focusing on vocational training and resettlement site development (Social). Commence construction of critical coastal protection infrastructure and deploy early warning systems in high-risk zones (Infrastructural). Scale up climate adaptation skills training nationally (Educational). Issue first tranche of Green Bonds (Fiscal). Intensify climate diplomacy for additional funding.
#     *   **Cost Estimate:** $500 million - $1 billion (major infrastructure, scaled social programs).
#     *   **Financing:** MDB concessional loans (World Bank, ADB), Green Bonds, increased international grants, NCAF funds.
# *   **Years 6-10 (Consolidation & Long-term Resilience):**
#     *   Full-scale implementation of CRLTP, aiming to resettle 50% of the target population by year 10 (Social). Complete major coastal protection projects and ensure comprehensive early warning system coverage (Infrastructural). Institutionalize climate-resilient planning across all sectors (Legal/Regulatory). Evaluate and refine NCAF financing mechanisms.
#     *   **Cost Estimate:** $1-2 billion+ (ongoing resettlement, infrastructure maintenance, sustained adaptation efforts).
#     *   **Financing:** Sustained MDB loans, continued Green Bond issuance, NCAF (carbon tax, international contributions), public-private partnerships for resilient infrastructure.
#
# #### Order-of-Magnitude Cost Estimate (Goal 1):
#
# *   **Total over 10 years:** $1.5 - $3 billion (approx. 2-4% of cumulative 10-year GDP)
# *   **Realistic Financing:** 60% international grants/concessional loans, 20% Green Bonds/PPPs, 20% domestic carbon tax/budget reallocation.
#
# #### 5 Concrete, Measurable Metrics:
#
# 1.  **Vulnerable Population Relocated/Protected:** Percentage of the 1 million threatened population either successfully relocated to safer areas or benefiting from adequate coastal protection measures.
# 2.  **Coastal Erosion Rate Reduction:** Average annual reduction in the rate of coastal erosion in priority areas due to adaptation interventions.
# 3.  **Early Warning System Coverage & Response Time:** Percentage of coastal communities covered by multi-hazard early warning systems, and average time from alert to community response readiness.
# 4.  **Livelihood Diversification for Relocated Households:** Percentage increase in income derived from new, climate-resilient livelihoods for households participating in CRLTP.
# 5.  **Climate Adaptation Investment % of GDP:** Annual percentage of GDP invested in climate adaptation, tracking both domestic and international contributions.
#
# ---
#
# ### Goal 2: Manage Technological Unemployment While Fostering Broadly Shared Economic Growth
#
# **Objective:** Retrain and upskill 2.5 million workers (25% of the workforce) for future-ready jobs, foster a dynamic innovation ecosystem, and ensure the benefits of technological progress are widely distributed, not concentrated.
#
# #### Top 6 Policy Interventions:
#
# 1.  **Educational: National Digital & Future Skills Strategy (NDFSS)**
#     *   Radical overhaul of the education system from primary to tertiary: mandatory digital literacy, coding, data science, AI ethics, and critical thinking. Establish national "Future Skills Academies" for rapid reskilling/upskilling of adults, focusing on transferable soft skills (creativity, problem-solving) and hard skills for emerging sectors.
# 2.  **Social: Universal Basic Income (UBI) Pilot & Conditional Income Support**
#     *   Launch a targeted UBI pilot in communities most affected by automation, coupled with a national conditional income support program tied to participation in training/education or community service for displaced workers. This provides a safety net and incentivizes reskilling.
# 3.  **Fiscal: "Future of Work" Tax Incentives & Innovation Fund**
#     *   Offer tax credits to companies investing in employee reskilling, adopting automation responsibly (e.g., collaborative robots that augment human work), and establishing R&D centers in strategic tech areas. Create a dedicated "Innovation Fund" to support local tech startups, especially those addressing national challenges (e.g., climate tech, agritech).
# 4.  **Infrastructural: Ubiquitous High-Speed Digital Infrastructure**
#     *   Invest heavily in nation-wide, affordable fiber optic broadband and 5G connectivity, especially in rural and remote areas. Establish accessible public digital hubs with free internet and training resources.
# 5.  **Regulatory: AI Ethics & Data Governance Framework**
#     *   Develop a national strategy for ethical AI development and deployment, including data privacy laws, algorithmic transparency requirements, and guidelines for AI in public services, balancing innovation with protection.
# 6.  **International/Political: Tech & Education Partnerships**
#     *   Forge strategic partnerships with leading tech nations, international universities, and global tech companies (e.g., Google, Microsoft, Amazon) for curriculum development, trainer exchange, joint research, and market access for local tech talent/startups.
#
# #### Sequencing and Timelines:
#
# *   **Years 0-2 (Foundation & Pilot Programs):**
#     *   Launch NDFSS: Revise national curriculum framework; establish 3-5 pilot Future Skills Academies (Educational). Conduct national job displacement risk assessment. Design and launch targeted UBI pilot (Social). Pass "Future of Work" tax incentives (Fiscal). Begin fiber optic rollout in major cities (Infrastructural). Establish initial AI ethics working group (Regulatory).
#     *   **Cost Estimate:** $100-200 million (curriculum development, academies, UBI pilot, initial infra).
#     *   **Financing:** MDB loans (education/digital transformation), budget reallocation, "Future of Work" tax revenues, initial tech partnerships.
# *   **Years 3-5 (Scaling & Ecosystem Building):**
#     *   Scale NDFSS nationally; expand Future Skills Academies to cover all regions; introduce mandatory digital literacy in schools (Educational). Expand UBI pilot, refine conditional income support (Social). Launch Innovation Fund (Fiscal). Accelerate rural broadband and 5G deployment (Infrastructural). Implement AI ethics framework (Regulatory). Secure more tech partnerships.
#     *   **Cost Estimate:** $750 million - $1.5 billion (significant education expansion, broader UBI, infra rollout).
#     *   **Financing:** MDB loans, dedicated Innovation Fund, private sector investment (attracted by incentives), increased tech partnership contributions.
# *   **Years 6-10 (Consolidation & Innovation Leadership):**
#     *   NDFSS fully embedded, continuous curriculum updates based on market needs (Educational). Conditional income support fully operational, ensuring safety net for all displaced workers (Social). Innovation Fund supports thriving tech startup ecosystem (Fiscal). Universal high-speed digital infrastructure achieved (Infrastructural). National AI strategy positions the country as a responsible innovator (Regulatory). Deepened international collaborations.
#     *   **Cost Estimate:** $1-2 billion+ (sustained education, ongoing income support, infrastructure maintenance/upgrades).
#     *   **Financing:** Domestic budget (tax revenues from new sectors), private sector, MDB repayments/new rounds, international partnerships.
#
# #### Order-of-Magnitude Cost Estimate (Goal 2):
#
# *   **Total over 10 years:** $2 - $4 billion (approx. 2.5-5% of cumulative 10-year GDP)
# *   **Realistic Financing:** 40% MDB loans, 30% domestic budget reallocation/tax incentives, 20% private sector (FDI, local investment), 10% international tech partnerships/grants.
#
# #### 5 Concrete, Measurable Metrics:
#
# 1.  **Workforce Reskilling/Upskilling Rate:** Number/percentage of adult workforce completing NDFSS programs and certified in future skills.
# 2.  **Job Displacement Rate vs. New Job Creation Rate:** Ratio of jobs lost to automation vs. new jobs created in emerging sectors (aim for ratio < 1).
# 3.  **Digital Skills Proficiency Index:** National average score on a standardized digital skills assessment for both students and adults.
# 4.  **Innovation Ecosystem Health:** Number of tech startups established, patents filed, and FDI in tech sectors.
# 5.  **Income Equality (Gini Coefficient):** Reduction in the Gini coefficient, demonstrating more broadly shared economic growth.
#
# ---
#
# ### Goal 3: Diversify and Harden the Economy Against External Shocks
#
# **Objective:** Reduce dependence on the single export commodity, develop multiple resilient export sectors, build strategic reserves, and enhance overall economic stability and competitiveness.
#
# #### Top 6 Policy Interventions:
#
# 1.  **Fiscal: Sectoral Diversification & Value-Added Incentives**
#     *   Implement targeted tax holidays, investment grants, and export subsidies for high-potential, non-commodity sectors (e.g., sustainable aquaculture, renewable energy tech manufacturing, high-value eco-tourism, digital services, specialized light manufacturing). Prioritize value-added processing of existing and new commodities.
# 2.  **International/Political: Proactive Trade & Investment Promotion Strategy**
#     *   Negotiate new bilateral and regional trade agreements to gain preferential access to diverse markets. Establish an aggressive national investment promotion agency (IPA) with overseas offices to attract FDI in target diversification sectors, offering streamlined regulatory processes and strong IP protection.
# 3.  **Infrastructural: Multi-modal Logistics & Green Energy Transition**
#     *   Invest in modernizing ports, airports, and internal transport networks to improve trade efficiency. Develop renewable energy (solar, wind, geothermal) infrastructure to reduce energy costs, enhance energy security, and attract green industries.
# 4.  **Legal/Regulatory: Ease of Doing Business Reforms & IP Protection**
#     *   Streamline business registration, licensing, and permitting processes. Reform labor laws to be flexible while protecting workers' rights. Strengthen intellectual property rights (IPR) enforcement to attract tech and innovation-driven FDI.
# 5.  **Educational: Specialized Vocational & Higher Education for New Sectors**
#     *   Align vocational training and university programs with the needs of target diversification sectors (e.g., marine engineering, renewable energy technology, hospitality management, software development, advanced manufacturing). Encourage internships and apprenticeships.
# 6.  **Fiscal: Strategic National Reserves & Commodity Price Stabilization Fund**
#     *   Establish and consistently fund a sovereign wealth fund (if commodity revenues allow) or a dedicated commodity price stabilization fund to cushion against volatile export commodity prices. Build strategic reserves of critical imports (food, medicine, energy).
#
# #### Sequencing and Timelines:
#
# *   **Years 0-2 (Enabling Environment & Initial Targets):**
#     *   Implement initial "Ease of Doing Business" reforms and strengthen IPR (Legal/Regulatory). Launch IPA and participate in key international investment forums (International/Political). Announce initial sectoral diversification incentives (Fiscal). Conduct feasibility studies for new port/logistics upgrades and renewable energy projects (Infrastructural). Begin aligning education with 2-3 priority new sectors (Educational). Establish Commodity Price Stabilization Fund.
#     *   **Cost Estimate:** $75-150 million (IPA setup, initial reforms, studies, fund capitalization).
#     *   **Financing:** Budget reallocation, initial commodity revenues, MDB technical assistance.
# *   **Years 3-5 (Investment & Infrastructure Build-out):**
#     *   Accelerate trade agreement negotiations and FDI attraction efforts (International/Political). Scale up sectoral incentives as new investments materialize (Fiscal). Commence construction of priority logistics infrastructure (ports, internal transport) and key renewable energy projects (Infrastructural). Expand specialized education and vocational training for 5-7 new sectors (Educational). Actively manage Commodity Price Stabilization Fund.
#     *   **Cost Estimate:** $1-2 billion (significant infrastructure, sustained incentives).
#     *   **Financing:** FDI, MDB loans (infrastructure), private sector investment, commodity revenues, Green Bonds (for green energy infra).
# *   **Years 6-10 (Diversification & Hardening Maturation):**
#     *   Multiple new export sectors mature, contributing significantly to GDP and employment (Fiscal). Diversified trade relationships and strong FDI pipeline (International/Political). Modern, efficient, green energy-powered logistics backbone in place (Infrastructural). Education system dynamically responsive to industry needs (Educational). Strategic reserves fully capitalized, economy resilient to commodity price fluctuations (Fiscal).
#     *   **Cost Estimate:** $1.5-3 billion+ (ongoing infrastructure, market development, fund growth).
#     *   **Financing:** New tax revenues from diversified economy, MDB loans, private sector investment, continued FDI, commodity stabilization fund, budget surplus.
#
# #### Order-of-Magnitude Cost Estimate (Goal 3):
#
# *   **Total over 10 years:** $2.5 - $5 billion (approx. 3-6% of cumulative 10-year GDP)
# *   **Realistic Financing:** 40% FDI, 30% MDB loans/PPPs, 20% domestic budget/commodity revenues, 10% trade promotion grants/bilateral aid.
#
# #### 5 Concrete, Measurable Metrics:
#
# 1.  **Non-Commodity Export Value % of Total Exports:** Increase in the percentage of export revenue derived from non-traditional commodities.
# 2.  **Economic Complexity Index (ECI):** Improvement in the country's ECI ranking, reflecting a more diversified and sophisticated production structure.
# 3.  **FDI in Diversification Sectors:** Annual volume of Foreign Direct Investment (FDI) attracted to targeted non-commodity sectors.
# 4.  **Energy Mix & Security:** Percentage of national energy supply from renewable sources, and number of months of critical import reserves.
# 5.  **Ease of Doing Business Ranking:** Improvement in international "Ease of Doing Business" or similar competitiveness indices.
#
# ---
#
# ### Overall Strategy Total Cost and Financing Summary
#
# *   **Estimated Total Cost (10 years):** Approximately **$6 - $12 billion** (7.5% - 15% of cumulative 10-year GDP)
# *   **Overall Financing Strategy:**
#     *   **International:** ~50% (Climate Finance grants, MDB concessional loans, bilateral aid, tech partnerships). *Requires aggressive, skilled diplomacy.*
#     *   **Foreign Direct Investment (FDI) & Private Sector:** ~20% (Attracted by reforms, incentives, and new infrastructure).
#     *   **Domestic (Government Budget & Innovative Mechanisms):** ~30% (Reallocation, carbon tax, sovereign green bonds, commodity stabilization fund, progressive taxation, PPPs). *Requires significant political will and fiscal discipline.*
#
# ---
#
# ### Three Most Plausible Failure Modes for the Overall Strategy
#
# 1.  **Political Paralysis and Lack of Consensus:** Deepening political polarization, resistance from vested interests tied to the single commodity, or short-term electoral cycles could prevent the sustained, cross-party commitment needed for a long-term strategy. This could manifest as budget cuts to critical programs, stalled legislative reforms, or a reversal of policy direction.
#     *   **Contingency Plan:**
#         *   **Broad-Based National Dialogue:** Establish a non-partisan "Future of the Nation" commission involving all political parties, civil society, business, and academia to build a shared understanding of the existential threats and the necessity of the strategy.
#         *   **Early Wins & Public Communication:** Prioritize visible, impactful projects with tangible benefits in the initial years (e.g., successful community relocation, quick job retraining successes) and communicate these effectively to build public trust and generate momentum.
#         *   **Constitutional Mandates:** Explore enshrining key elements of climate adaptation and human capital development in constitutional or framework legislation that is harder to overturn, making future governments accountable.
#         *   **External Pressure & Support:** Leverage international partners to provide technical assistance and funding conditional on policy continuity and consensus.
#
# 2.  **Insufficient International Support/Financing:** Despite aggressive diplomacy, the scale of required international climate finance and development aid may not materialize, leaving critical adaptation projects, technology transfer, and social safety nets severely underfunded.
#     *   **Contingency Plan:**
#         *   **"Plan B" Prioritization:** Develop a tiered prioritization of projects. If international funding falls short, focus solely on the most critical, life-saving climate adaptation and essential human capital development (e.g., core reskilling for basic services).
#         *   **Enhanced Domestic Mobilization:** Double down on innovative domestic financing (e.g., higher carbon tax, progressive wealth tax, more aggressive asset recovery, private sector co-financing through PPPs, diaspora bonds) and explore debt-for-climate swaps.
#         *   **Regional Cooperation:** Seek stronger regional partnerships for shared climate infrastructure and economic diversification, leveraging collective bargaining power for international support.
#         *   **Phased Implementation & Modular Projects:** Design projects to be modular and scalable, allowing for incremental implementation as funding becomes available, rather than relying on a single large-scale tranche.
#
# 3.  **Faster-than-Expected Climate Impacts or Technological Disruption:** The pace of sea-level rise accelerates beyond current projections, or AI/automation advances much faster and more pervasively than anticipated, overwhelming adaptation capacities and job creation efforts.
#     *   **Contingency Plan:**
#         *   **Dynamic Monitoring & Adaptive Management:** Establish a dedicated "Futures Monitoring Unit" with experts constantly tracking global climate and technological trends, updating projections, and assessing the strategy's effectiveness against evolving threats.
#         *   **Built-in Flexibility:** Design infrastructure and policy interventions with flexibility for rapid adjustment (e.g., coastal defenses that can be augmented, education programs with agile curriculum updates).
#         *   **Enhanced Redundancy & Decentralization:** For climate, build redundancy into critical infrastructure and promote decentralized, community-level adaptation. For technology, ensure multiple pathways for reskilling and a diverse set of emerging industries to hedge against single sector collapse.
#         *   **International Rapid Response Mechanisms:** Advocate for and participate in international frameworks for rapid climate disaster response and global coordination on managing AI/automation impacts.
#
# ---
#
# ### Key Assumptions & Empirical Indicators for Revision
#
# *   **CZMRA (Goal 1, Legal):**
#     *   *Assumptions:* Government capacity to enforce land use laws; willingness of communities to relocate with fair compensation; accurate scientific data for zone mapping.
#     *   *Indicators for Revision:* Widespread non-compliance with building codes; significant public resistance to relocation plans despite compensation; inaccurate climate modeling leading to misidentification of risk zones.
# *   **CRLTP (Goal 1, Social):**
#     *   *Assumptions:* Availability of suitable relocation sites; effective psychosocial support to manage displacement trauma; successful integration of relocated populations into new economies.
#     *   *Indicators for Revision:* High rates of return migration to vulnerable zones; increased social unrest or poverty in resettlement areas; failure of new livelihood programs to sustain relocated families.
# *   **NCAF & Green Bonds (Goal 1, Fiscal):**
#     *   *Assumptions:* Stable international investor confidence for green bonds; domestic political will for carbon tax implementation and collection; effective governance of the fund.
#     *   *Indicators for Revision:* Under-subscription of green bonds; public outcry or business lobbying leading to rollback of carbon tax; evidence of corruption or mismanagement of the fund.
# *   **NDFSS & Future Skills Academies (Goal 2, Educational):**
#     *   *Assumptions:* Sufficient number of qualified educators; industry demand for newly trained skills; high participation rates from adult learners.
#     *   *Indicators for Revision:* Low enrollment rates in academies; high unemployment rates among graduates of NDFSS programs; a significant mismatch between skills taught and industry needs.
# *   **UBI Pilot & Conditional Income Support (Goal 2, Social):**
#     *   *Assumptions:* UBI does not disincentivize work/training beyond acceptable levels; adequate fiscal resources for scaling; effective targeting of beneficiaries.
#     *   *Indicators for Revision:* Significant drop in labor force participation among UBI recipients without corresponding increase in training/education; unsustainable cost projections upon scaling; high rates of benefit fraud.
# *   **"Future of Work" Tax Incentives (Goal 2, Fiscal):**
#     *   *Assumptions:* Incentives genuinely stimulate desired corporate behavior (R&D, reskilling, responsible automation); sufficient corporate profits to benefit from incentives; incentives do not lead to significant tax revenue loss without commensurate economic benefits.
#     *   *Indicators for Revision:* Low uptake of incentives by companies; companies using incentives for "tax arbitrage" without real investment in reskilling/R&D; a decline in overall tax revenue without a measurable increase in innovation or employment.
# *   **Sectoral Diversification Incentives (Goal 3, Fiscal):**
#     *   *Assumptions:* Global market demand for new export products; local entrepreneurs and investors respond to incentives; effective competition from established global players.
#     *   *Indicators for Revision:* Low investment in new sectors despite incentives; failure of new export products to gain market share; high failure rate of businesses in target sectors.
# *   **Trade & Investment Promotion Strategy (Goal 3, International):**
#     *   *Assumptions:* Political stability and rule of law remain strong; trade partners are willing to negotiate favorable agreements; global FDI flows remain robust.
#     *   *Indicators for Revision:* Decline in FDI inflows despite promotion efforts; breakdown of trade agreement negotiations; significant investor complaints about regulatory hurdles or corruption.
# *   **Multi-modal Logistics & Green Energy Transition (Goal 3, Infrastructural):**
#     *   *Assumptions:* Timely and budget-compliant completion of projects; sufficient private sector participation in green energy; stable energy supply from renewables.
#     *   *Indicators for Revision:* Significant project delays or cost overruns; insufficient private investment in green energy; intermittent power supply due to over-reliance on a single renewable source or inadequate storage.
#
# ---
#
# ### Three Strongest Counterarguments and Rebuttals
#
# 1.  **Counterargument:** "This plan is far too ambitious and expensive for a small, middle-income nation with limited fiscal space and high debt. It risks bankrupting the country and neglecting immediate, pressing social needs for long-term, uncertain gains."
#     *   **Rebuttal:** "The costs of inaction far outweigh the costs of this integrated strategy. Ignoring sea-level rise means losing habitable land and productive capacity, leading to mass internal displacement, social unrest, and a permanent drain on public finances. Failing to address technological unemployment will create a massive underclass and severe social instability. Continued dependence on a single commodity leaves us perpetually vulnerable to global market whims. These are not 'long-term, uncertain gains' but *existential necessities*. While expensive, the strategy is designed for maximum leverage, actively seeking international climate finance, MDB loans, and private sector investment. Our debt, while concerning, is manageable, and this investment is a critical path to future debt sustainability by strengthening our economic base and generating new revenue streams. We are prioritizing strategic, co-beneficial investments that are cheaper than future crises."
#
# 2.  **Counterargument:** "The plan relies too heavily on external actors and financing (international organizations, foreign investors). This compromises national sovereignty, creates dependency, and exposes the country to geopolitical risks and conditionalities that may not align with our national interests."
#     *   **Rebuttal:** "While leveraging international partnerships is crucial due to our fiscal constraints, this strategy carefully balances external support with robust domestic capacity building and strategic autonomy. We are not passively awaiting aid; we are proactively engaging, shaping terms, and attracting investment based on our national strategic plan. The goal is to *diversify* our international relationships and financing sources, reducing reliance on any single entity. Furthermore, the capacity we build through human capital development and economic diversification strengthens our negotiating position and reduces future dependency. True sovereignty in the 21st century comes from resilience, economic strength, and the ability to adapt, not from isolation. Many of these 'conditionalities' (e.g., good governance, fiscal transparency) are in our own national interest anyway."
#
# 3.  **Counterargument:** "The focus on climate adaptation and future technology ignores the immediate social and economic grievances that fuel current political polarization. Prioritizing these abstract, long-term threats will further alienate segments of the population who demand immediate relief and reinforce political divisions."
#     *   **Rebuttal:** "This plan directly addresses immediate social and economic grievances by focusing on human capital and equitable growth. The Universal Basic Income pilot and conditional income support provide immediate relief for those displaced by technology. The Climate Relocation and Livelihood Transition Program directly supports vulnerable communities with housing, training, and jobs. Investments in digital infrastructure extend connectivity and opportunities to all regions. By creating new jobs in emerging sectors and expanding access to education, we are tackling the root causes of inequality and providing pathways to prosperity for all citizens, not just a select few. Communicating these direct benefits and involving communities in co-designing solutions is paramount to building consensus and bridging political divides. This isn't just about long-term survival; it's about immediate, tangible improvements in people's lives that foster hope and shared purpose."
#
# ---
#
# ### Probabilistic Estimate of Success
#
# (Given effective implementation and reasonable external conditions)
#
# 1.  **Goal 1: Protect and adapt vulnerable populations to climate displacement.**
#     *   **Probability: 60%.**
#     *   **Justification:** This goal faces high technical and social complexity (e.g., large-scale relocation), significant funding requirements, and the unpredictable nature of climate change itself. However, the proactive strategy, emphasis on legal frameworks, international funding leverage, and community engagement increases the chances of measurable progress on protection and orderly adaptation for a significant portion of the threatened population within 10 years, even if not all 1 million are fully adapted.
#
# 2.  **Goal 2: Manage technological unemployment while fostering broadly shared economic growth.**
#     *   **Probability: 55%.**
#     *   **Justification:** This goal is highly dependent on the speed and nature of technological disruption (which is hard to predict), the agility of the education system, and the willingness of the workforce to retrain. The UBI pilot and strong social safety nets provide a crucial buffer. The interconnectedness with Goal 3 (diversification creating new jobs) boosts this probability. However, significant fiscal resources are needed for retraining and income support, and successfully shifting cultural attitudes towards lifelong learning is a major undertaking.
#
# 3.  **Goal 3: Diversify and harden the economy against external shocks.**
#     *   **Probability: 65%.**
#     *   **Justification:** This goal benefits from clear policy levers (fiscal incentives, trade deals, infrastructure, ease of doing business) and strong international interest in investment in stable, growing markets. Diversification away from a single commodity is a common development challenge, but the specific focus on green industries and digital services aligns with global trends. The availability of FDI and MDB support is a strong factor. The risk lies in global economic downturns or unforeseen trade barriers, but the internal reforms are designed to build inherent resilience.

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# Updated with the latest Open Source model from OpenAI

groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# So where are we?

print(competitors)
print(answers)

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
