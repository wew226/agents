# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key not set (and this is optional)
# Google API Key not set (and this is optional)
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# Imagine you are advising the government of a mid-sized democratic country that has discovered a new AI-driven agricultural technology that could double crop yields within five years but would also displace roughly 40% of agricultural workers, accelerate consolidation among large agribusinesses, and strain rural communities; the country has limited fiscal space, rising inequality, and an election in 18 months. Provide one concise answer that includes the following:
#
# 1) List up to six key uncertainties and value trade-offs the government must consider.
#
# 2) Propose three distinct policy packages (A: prioritize rapid adoption for GDP growth; B: prioritize equity and social cohesion; C: a balanced compromise). For each package give four concrete measures, and estimate short-term (0–3 years) and medium-term (3–10 years) effects on GDP, employment, inequality (Gini or qualitative), food security, and political stability, using approximate probability ranges for outcomes (e.g., 20–60% chance of X).
#
# 3) For each package, identify the top three risks and one early-warning indicator to monitor within the first two years that would justify pivoting policy.
#
# 4) Recommend one package and justify the choice in no more than 150 words, explicitly listing three assumptions that must hold for your recommendation to be valid.
#
# 5) Describe two ways your analysis could be biased or wrong and specify two types of empirical data that would most reduce the largest remaining uncertainties.
#
# At the end, state succinctly (one line) which analytical methods you used (e.g., scenario analysis, cost–benefit reasoning, Bayesian updating) and give a calibrated confidence level (0–100%) in your recommendation.

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# 1) Key uncertainties and value trade-offs (up to six)
#
# - Adoption speed vs displacement: how rapidly AI agro-tech can be scaled and integrated, weighed against the 40% of agricultural workers who could be displaced and need meaningful alternatives.
# - Inequality and rural cohesion: whether benefits accrue mainly to large firms and landowners, or are shared with smallholders and rural communities, affecting social harmony and political support.
# - Fiscal space and cost of policy mix: whether subsidies, retraining, safety nets, and infrastructure can be financed without unsustainable debt or crowds-out of other essential public services.
# - Market structure and competition: risk of accelerated consolidation among large agribusinesses and potential price-power that hurts smallholders unless mitigated.
# - Food security resilience: reliance on AI-enabled yields and supply chains in the face of shocks (climate, pests, cyber risks) and possible disruptions during transition.
# - Governance and AI risks: data privacy, safety, interoperability, ethics, and dependence on a few technology providers; need for robust governance and standards.
#
# 2) Three policy packages (A, B, C) with four measures each, and estimated short-term (0–3 years) and medium-term (3–10 years) effects
#
# Package A: prioritize rapid adoption for GDP growth
# Four concrete measures
# - Accelerate adoption incentives: targeted subsidies, tax credits, and fast-track approvals for farms that implement the AI tech, with interoperability standards.
# - Public–private extension and infrastructure push: scale extension services, broadband and digital farming platforms to support uptake.
# - Transitional wage subsidies and retraining-lite: modest subsidies to employers to retain workers during initial deployment and to enroll workers in short retraining modules.
# - Competition and interoperability safeguards: open data standards, anti-monopoly enforcement, and procurement rules to prevent vendor lock-in.
#
# Estimated effects (ranges; with probability bands)
# - GDP: Short-term +0.5–2.0 percentage points in annual growth (0–3 years); Medium-term +2.0–5.0 percentage points (3–10 years). Probability of net GDP gain in 0–3 years: 40–70%.
# - Employment: Short-term net employment change in agriculture −4% to −12% (displacement); overall economy −0% to −2% (net). Medium-term: −1% to +2% overall. Probability of meaningful employment stress in 0–3 years: 40–60%.
# - Inequality: Short-term Gini up 0.5–2 points; medium-term uncertain but could persist if benefits skew to adopters; probability of worsening inequality in 0–3 years: 40–65%.
# - Food security: Short-term price volatility or local supply frictions 20–40% probability; medium-term improved yields and supply 60–80% probability.
# - Political stability: Short-term unrest risk moderate (20–40% probability); medium-term uncertainty but potential stabilization if gains are visible (40–60% probability).
#
# Top three risks and early-warning indicator
# - Risks: (1) Worsening rural inequality and social unrest if displaced workers are not absorbed; (2) Fiscal squeeze from subsidies and incentives; (3) Vendor lock-in and reduced competition diminishing smallholders’ bargaining power.
# - Early-warning indicator: rural unemployment/underemployment rate rising by more than ~2 percentage points for two consecutive quarters.
#
# Package B: prioritize equity and social cohesion
# Four concrete measures
# - Expanded social protection and income support: targeted cash transfers, unemployment insurance, and healthcare access for rural households.
# - Comprehensive retraining and job-matching: funded programs, regional job centers, and guaranteed job placement for retrained workers.
# - Rural diversification and local opportunity creation: support for cooperatives, agro-processing, and alternative rural livelihoods; microfinance for smallholders.
# - Equitable access to technology: subsidized leasing or low-cost credit for smallholders, open access to AI tools, and capacity-building within communities.
#
# Estimated effects
# - GDP: Short-term +0.3–1.5 pp; medium-term +1.5–4.0 pp; probability of positive GDP impact in 0–3 years: 50–70%.
# - Employment: Short-term displacement still present (− labor share), but retraining and new rural jobs offset some losses: net −2% to −6% (0–3 years); medium-term 0% to +2% (3–10 years). Probability of net employment stabilization by year 5: 40–60%.
# - Inequality: Short-term Gini rise 0.5–1.5 points, with stronger redistribution effects over 3–10 years; probability of reduced inequality by 5–10 years: 30–50%.
# - Food security: Short-term risk mitigation; probability of stable to improved food security in 0–3 years: 60–75%.
# - Political stability: Higher risk of protests if protections are perceived as insufficient; probability of stability improving over 3–10 years: 45–65%.
#
# Top three risks and early-warning indicator
# - Risks: (1) Insufficient fiscal space to sustain protections; (2) Skill mismatch and poor job placements reducing effectiveness; (3) Ineffective access to technology for smallholders, widening gaps.
# - Early-warning indicator: uptake and continuity of retraining participation and placement success rate (e.g., share of retrained workers in stable jobs after 12 months falls below 50–60%).
#
# Package C: balanced compromise
# Four concrete measures
# - Performance-based subsidies: subsidies tied to retention of a portion of displaced workers and demonstrated retraining completion; sunset clauses to avoid feebacks.
# - Targeted social protection with phased exposure: modest safety nets plus time-limited support to bridge transitions; progressively taper as labor markets absorb new roles.
# - Regulatory guardrails and data governance: enforce antitrust rules, open data standards, and transparent pricing; ensure interoperability and prevent monopolies.
# - Public extension and rural infrastructure investment: expand extension services, farmer training, and rural transport/internet connectivity to ensure broad access to the technology.
#
# Estimated effects
# - GDP: Short-term +0.7–2.2 pp; medium-term +2.0–4.5 pp; probability of positive GDP impact in 0–3 years: 50–70%.
# - Employment: Short-term displacement −5% to −10% in agriculture; medium-term net −0% to +2% as reemployment rises; probability of stabilization by year 5: 45–65%.
# - Inequality: Short-term Gini +0.5–1.5 points; medium-term risk of erosion reduced if protections work; probability of narrowing inequality by year 7: 25–45%.
# - Food security: Short-term stabilization risks remain but longer-term yields improve; 0–3 years: 30–50% risk; 3–10 years: 70–85% improvement in food security.
# - Political stability: Moderate risk of unrest in early years but higher probability of stabilization with social protections; 0–3 years: 25–45%; 3–10 years: 50–70%.
#
# Top three risks and early-warning indicator
# - Risks: (1) Insufficient execution capacity to deliver subsidies and retraining; (2) Social protection costs becoming unsustainable; (3) Partial adoption undermining expected productivity gains.
# - Early-warning indicator: share of displaced workers who remain in transition programs or have found stable employment after 12–24 months; if below 60%, pivot attention to deeper protections or broader retraining.
#
# 3) For each package: top three risks and one early-warning indicator
#
# - Package A
#   - Top risks: unequal gains to adopters, fiscal strain, loss of smallholders’ bargaining power.
#   - Early-warning indicator: rural unemployment rate rising by >2 pp for two consecutive quarters.
# - Package B
#   - Top risks: fiscal sustainability of social protections, ineffective job placement, tech access gaps for smallholders.
#   - Early-warning indicator: protests or social instability index rising; or retraining uptake lagging (more than 6 months with stagnant placement).
# - Package C
#   - Top risks: execution risk (getting programs up and running), costs of protections, underutilization of devices and training.
#   - Early-warning indicator: retention/placement rate for retrained workers below 60% after 12 months.
#
# 4) One recommended package (and why) with three assumptions (≤150 words)
#
# Recommendation: Package C (balanced compromise). Why: it aligns GDP growth with social protection, preserves rural cohesion, and builds governance to curb consolidation and protect smallholders, while keeping fiscal risks more manageable than full protection-only (B) and avoiding the aggressive risk of displacement under A. Three assumptions:
# - Effective design and delivery of performance-based subsidies and retraining, with credible sunset clauses and transparent metrics.
# - Sufficient fiscal headroom to fund targeted social protections and modest subsidies without compromising essential services.
# - Robust governance, anti-trust enforcement, open data standards, and cooperation from tech providers to prevent monopolization and ensure interoperability.
#
# 5) Two ways the analysis could be biased or wrong; two data types to reduce key uncertainties
#
# Bias risks:
# - Optimistic tech adoption bias: overestimating pace and productivity gains, underestimating social and political costs.
# - Underappreciation of local variation: assuming uniform rural impact and capacity to absorb workers across regions.
#
# Two empirical data types to reduce uncertainty:
# - Microlevel longitudinal data on farm-level AI adoption, yields, input use, and labor transitions (household surveys plus farm records).
# - Administrative records on retraining participation, job placements, wages, and firm market shares (employment, unemployment, wages, and concentration metrics), plus timely rural poverty and inequality indicators.
#
# End-of-answer concise synthesis: analytical methods used and confidence
# - Methods used: scenario analysis, cost–benefit reasoning, and framing with risk indicators; qualitative intuition checked against quantitative ranges; basic Bayesian updating for evolving evidence.
# - Calibrated confidence in the recommendation: 60%

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-sonnet-4-5"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# Updated with the latest Open Source model from OpenAI

groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# So where are we?

print(competitors)
print(answers)

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
